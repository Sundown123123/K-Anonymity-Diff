# %%
import pandas as pd
import matplotlib.pylab as pl
import matplotlib.patches as patches

# %%
# dataframe 显示所有数据
pd.set_option('display.max_rows', 50)

# %%
# 属性列名
names = (
    'age',
    'workclass', 
    'fnlwgt', 
    'education',
    'education-num',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'capital-gain',
    'capital-loss',
    'hours-per-week',
    'native-country',
    'income',
)
# 分类数据
categorical = set((
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'sex',
    'native-country',
    'race',
    'income',
))

# %%
df = pd.read_csv("adult.data.txt", sep=", ", header=None, names=names, index_col=False, engine='python')

# %%
df.head(80)
# Out:
#     age         workclass  fnlwgt   education  education-num  \
# 0    39         State-gov   77516   Bachelors             13
# 1    50  Self-emp-not-inc   83311   Bachelors             13
# 2    38           Private  215646     HS-grad              9
# 3    53           Private  234721        11th              7
# 4    28           Private  338409   Bachelors             13
# ..  ...               ...     ...         ...            ...
# 75   27           Private  213921     HS-grad              9
# 76   40           Private   32214  Assoc-acdm             12
# 77   67                 ?  212759        10th              6
# 78   18           Private  309634        11th              7
# 79   31         Local-gov  125927     7th-8th              4
#
#         marital-status         occupation   relationship   race     sex  \
# 0        Never-married       Adm-clerical  Not-in-family  White    Male
# 1   Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2             Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3   Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4   Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ..                 ...                ...            ...    ...     ...
# 75       Never-married      Other-service      Own-child  White    Male
# 76  Married-civ-spouse       Adm-clerical        Husband  White    Male
# 77  Married-civ-spouse                  ?        Husband  White    Male
# 78       Never-married      Other-service      Own-child  White  Female
# 79  Married-civ-spouse    Farming-fishing        Husband  White    Male
#
#     capital-gain  capital-loss  hours-per-week native-country income
# 0           2174             0              40  United-States  <=50k
# 1              0             0              13  United-States  <=50k
# 2              0             0              40  United-States  <=50k
# 3              0             0              40  United-States  <=50k
# 4              0             0              40           Cuba  <=50k
# ..           ...           ...             ...            ...    ...
# 75             0             0              40         Mexico  <=50k
# 76             0             0              40  United-States  <=50k
# 77             0             0               2  United-States  <=50k
# 78             0             0              22  United-States  <=50k
# 79             0             0              40  United-States  <=50k
#
# [80 rows x 15 columns]

# %%
#astype()方法显式地把一种数据类型转换为另一种
for name in categorical:
    df[name] = df[name].astype('category')

# %%
# 计算分区中所有列的跨度，如果给定了规模，那么每列的跨度值会被该列的规模除，得到的就是相对跨度
def get_spans(df, partition, scale=None):
    spans = {}
    for column in df.columns:
        if column in categorical:
            span = len(df[column][partition].unique())
        else:
            span = df[column][partition].max()-df[column][partition].min()
        if scale is not None:
            span = span/scale[column]
        spans[column] = span
    return spans

# %%
full_spans = get_spans(df, df.index)

# %%
full_spans
# Out:
# {'age': 73,
#  'workclass': 9,
#  'fnlwgt': 1472420,
#  'education': 16,
#  'education-num': 15,
#  'marital-status': 7,
#  'occupation': 15,
#  'relationship': 6,
#  'race': 5,
#  'sex': 2,
#  'capital-gain': 99999,
#  'capital-loss': 4356,
#  'hours-per-week': 98,
#  'native-country': 42,
#  'income': 2}

# %%
def split(df, partition, column):
    
    dfp = df[column][partition]
    if column in categorical:
        values = dfp.unique()
        lv = set(values[:len(values)//2])
        rv = set(values[len(values)//2:])
        return dfp.index[dfp.isin(lv)], dfp.index[dfp.isin(rv)]
    else:        
        median = dfp.median()
        dfl = dfp.index[dfp < median]
        dfr = dfp.index[dfp >= median]
        return (dfl, dfr)

# %%
def is_k_anonymous(df, partition, sensitive_column, k=5):
   
    if len(partition) < k:
        return False
    return True

def partition_dataset(df, feature_columns, sensitive_column, scale, is_valid):
    
    finished_partitions = []
    partitions = [df.index]
    while partitions:
        partition = partitions.pop(0)
        spans = get_spans(df[feature_columns], partition, scale)
        for column, span in sorted(spans.items(), key=lambda x:-x[1]):
            lp, rp = split(df, partition, column)
            if not is_valid(df, lp, sensitive_column) or not is_valid(df, rp, sensitive_column):
                continue
            partitions.extend((lp, rp))
            break
        else:
            finished_partitions.append(partition)
    return finished_partitions

# %%
feature_columns = [
    'age',
    'workclass',
    'fnlwgt', 
    'education',
    'education-num',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'capital-gain',
    'capital-loss',
    'hours-per-week',
    'native-country'
]
sensitive_column = 'income'
finished_partitions = partition_dataset(df, feature_columns, sensitive_column, full_spans, is_k_anonymous)
print("OK")
# Out:
# OK

# %%
len(finished_partitions)
# Out:
# 5074

# %%
def agg_categorical_column(series):
    return [','.join(set(series))]

def agg_numerical_column(series):
    return series.mean()

# %%
def build_anonymized_dataset(df, partitions, feature_columns, sensitive_column, max_partitions=None):
    aggregations = {}
    for column in feature_columns:
        if column in categorical:
            aggregations[column] = agg_categorical_column
        else:
            aggregations[column] = agg_numerical_column
    rows = []
    for i, partition in enumerate(partitions):
        if i % 100 == 1:
            print("Finished {} partitions...".format(i))
        if max_partitions is not None and i > max_partitions:
            break
        grouped_columns = df.loc[partition].agg(aggregations, squeeze=False)
        sensitive_counts = df.loc[partition].groupby(sensitive_column).agg({sensitive_column : 'count'})
        #xdu_qinian insert
        df2=grouped_columns.to_frame()
        grouped_columns=pd.DataFrame(df2.values.T,columns=df2.index)
        #insert_end
        values = grouped_columns.iloc[0].to_dict()
        for sensitive_value, count in sensitive_counts[sensitive_column].items():
            if count == 0:
                continue
            values.update({
                sensitive_column : sensitive_value,
                'count' : count,

            })
            rows.append(values.copy())
    return pd.DataFrame(rows)

# %%
dfn = build_anonymized_dataset(df, finished_partitions, feature_columns, sensitive_column)
# Out:
# Finished 1 partitions...
# Finished 101 partitions...
# Finished 201 partitions...
# Finished 301 partitions...
# Finished 401 partitions...
# Finished 501 partitions...
# Finished 601 partitions...
# Finished 701 partitions...
# Finished 801 partitions...
# Finished 901 partitions...
# Finished 1001 partitions...
# Finished 1101 partitions...
# Finished 1201 partitions...
# Finished 1301 partitions...
# Finished 1401 partitions...
# Finished 1501 partitions...
# Finished 1601 partitions...
# Finished 1701 partitions...
# Finished 1801 partitions...
# Finished 1901 partitions...
# Finished 2001 partitions...
# Finished 2101 partitions...
# Finished 2201 partitions...
# Finished 2301 partitions...
# Finished 2401 partitions...
# Finished 2501 partitions...
# Finished 2601 partitions...
# Finished 2701 partitions...
# Finished 2801 partitions...
# Finished 2901 partitions...
# Finished 3001 partitions...
# Finished 3101 partitions...
# Finished 3201 partitions...
# Finished 3301 partitions...
# Finished 3401 partitions...
# Finished 3501 partitions...
# Finished 3601 partitions...
# Finished 3701 partitions...
# Finished 3801 partitions...
# Finished 3901 partitions...
# Finished 4001 partitions...
# Finished 4101 partitions...
# Finished 4201 partitions...
# Finished 4301 partitions...
# Finished 4401 partitions...
# Finished 4501 partitions...
# Finished 4601 partitions...
# Finished 4701 partitions...
# Finished 4801 partitions...
# Finished 4901 partitions...
# Finished 5001 partitions...

# %%
dfn=dfn.apply(lambda x: x.explode().astype(str).groupby(level=0).agg(", ".join))

# %%
dfn
# Out:
#                      age                           workclass  \
# 0                 25.875         Self-emp-inc,?,Never-worked
# 1                   27.0                         Local-gov,?
# 2                   27.0                         Local-gov,?
# 3     29.166666666666668                         Local-gov,?
# 4                   42.0  Self-emp-not-inc,Local-gov,Private
# ...                  ...                                 ...
# 7699                43.2                             Private
# 7700                42.0                             Private
# 7701                42.0                             Private
# 7702                43.6                             Private
# 7703                43.6                             Private
#
#                   fnlwgt                                education  \
# 0             190725.625        Some-college,7th-8th,10th,HS-grad
# 1               219007.6                              5th-6th,9th
# 2               219007.6                              5th-6th,9th
# 3     213259.16666666666                              5th-6th,9th
# 4     153341.88888888888  Some-college,Bachelors,9th,HS-grad,11th
# ...                  ...                                      ...
# 7699            113757.2                                Bachelors
# 7700            152689.2                                Bachelors
# 7701            152689.2                                Bachelors
# 7702            146092.8                                Bachelors
# 7703            146092.8                                Bachelors
#
#           education-num                                     marital-status  \
# 0                 8.375                                 Divorced,Separated
# 1                   4.2                   Married-civ-spouse,Never-married
# 2                   4.2                   Married-civ-spouse,Never-married
# 3                   4.0                   Separated,Divorced,Never-married
# 4     9.777777777777779  Married-spouse-absent,Married-AF-spouse,Separa...
# ...                 ...                                                ...
# 7699               13.0                                 Married-civ-spouse
# 7700               13.0                                 Married-civ-spouse
# 7701               13.0                                 Married-civ-spouse
# 7702               13.0                                 Married-civ-spouse
# 7703               13.0                                 Married-civ-spouse
#
#                                              occupation  \
# 0                         Prof-specialty,Adm-clerical,?
# 1                      Craft-repair,?,Handlers-cleaners
# 2                      Craft-repair,?,Handlers-cleaners
# 3                                       ?,Other-service
# 4     Handlers-cleaners,Prof-specialty,Transport-mov...
# ...                                                 ...
# 7699                                    Exec-managerial
# 7700                                    Exec-managerial
# 7701                                    Exec-managerial
# 7702                                    Exec-managerial
# 7703                                    Exec-managerial
#
#                                           relationship  \
# 0     Own-child,Unmarried,Not-in-family,Other-relative
# 1                               Other-relative,Husband
# 2                               Other-relative,Husband
# 3                                            Unmarried
# 4                                    Own-child,Husband
# ...                                                ...
# 7699                                           Husband
# 7700                                           Husband
# 7701                                           Husband
# 7702                                           Husband
# 7703                                           Husband
#
#                                       race     sex       capital-gain  \
# 0                 Amer-Indian-Eskimo,White    Male                0.0
# 1                              Black,White    Male                0.0
# 2                              Black,White    Male                0.0
# 3                        Black,Other,White  Female                0.0
# 4     Asian-Pac-Islander,Black,Other,White    Male  810.8888888888889
# ...                                    ...     ...                ...
# 7699                                 White    Male              620.6
# 7700                                 White    Male             1663.0
# 7701                                 White    Male             1663.0
# 7702                                 White    Male             1459.6
# 7703                                 White    Male             1459.6
#
#      capital-loss      hours-per-week  \
# 0             0.0              29.125
# 1           343.8                36.0
# 2           343.8                36.0
# 3             0.0  39.333333333333336
# 4             0.0   41.77777777777778
# ...           ...                 ...
# 7699          0.0                40.0
# 7700          0.0                40.0
# 7701          0.0                40.0
# 7702          0.0                40.0
# 7703          0.0                40.0
#
#                                          native-country income count
# 0                                         United-States  <=50k     8
# 1     Trinadad&Tobago,El-Salvador,Mexico,United-Stat...  <=50k     3
# 2     Trinadad&Tobago,El-Salvador,Mexico,United-Stat...   >50k     2
# 3                      United-States,El-Salvador,Mexico  <=50k     6
# 4                                United-States,?,Mexico  <=50k     8
# ...                                                 ...    ...   ...
# 7699                                      United-States   >50k     4
# 7700                                      United-States  <=50k     1
# 7701                                      United-States   >50k     4
# 7702                                      United-States  <=50k     1
# 7703                                      United-States   >50k     4
#
# [7704 rows x 16 columns]

# %%
dfn.sort_values(feature_columns+[sensitive_column])
# Out:
#                     age                   workclass              fnlwgt  \
# 3371               17.0                           ?  126071.66666666667
# 1755               17.0                     Private            168794.4
# 1772               17.0                     Private            199233.0
# 1208               17.0                     Private  236435.66666666666
# 1767               17.0                     Private             69810.8
# ...                 ...                         ...                 ...
# 2624  79.83333333333333  Self-emp-not-inc,Local-gov            128250.5
# 2625  79.83333333333333  Self-emp-not-inc,Local-gov            128250.5
# 5134               81.0                 Local-gov,?  166264.16666666666
# 5135               81.0                 Local-gov,?  166264.16666666666
# 1451               81.6  Self-emp-not-inc,?,Private            178653.2
#
#                       education      education-num  \
# 3371                       10th                6.0
# 1755                       10th                6.0
# 1772                       11th                7.0
# 1208                       10th                6.0
# 1767                       11th                7.0
# ...                         ...                ...
# 2624  HS-grad,Some-college,11th  8.833333333333334
# 2625  HS-grad,Some-college,11th  8.833333333333334
# 5134                    HS-grad                9.0
# 5135                    HS-grad                9.0
# 1451       Some-college,HS-grad                9.2
#
#                                  marital-status  \
# 3371                              Never-married
# 1755                              Never-married
# 1772                              Never-married
# 1208                              Never-married
# 1767                              Never-married
# ...                                         ...
# 2624  Divorced,Married-civ-spouse,Never-married
# 2625  Divorced,Married-civ-spouse,Never-married
# 5134                         Married-civ-spouse
# 5135                         Married-civ-spouse
# 1451              Married-spouse-absent,Widowed
#
#                                 occupation           relationship   race  \
# 3371                                     ?              Own-child  White
# 1755                         Other-service              Own-child  White
# 1772                                 Sales              Own-child  White
# 1208                         Other-service              Own-child  White
# 1767                    Sales,Adm-clerical              Own-child  White
# ...                                    ...                    ...    ...
# 2624    Craft-repair,Sales,Exec-managerial  Not-in-family,Husband  White
# 2625    Craft-repair,Sales,Exec-managerial  Not-in-family,Husband  White
# 5134                       ?,Other-service                Husband  White
# 5135                       ?,Other-service                Husband  White
# 1451  Prof-specialty,Sales,?,Other-service          Not-in-family  White
#
#          sex        capital-gain capital-loss hours-per-week  \
# 3371    Male                 0.0          0.0           40.0
# 1755  Female                 0.0          0.0           13.2
# 1772  Female                 0.0        320.4           14.2
# 1208    Male                 0.0          0.0           19.0
# 1767  Female               422.0          0.0           19.8
# ...      ...                 ...          ...            ...
# 2624    Male               885.0          0.0           10.5
# 2625    Male               885.0          0.0           10.5
# 5134    Male  1127.8333333333333          0.0           40.0
# 5135    Male  1127.8333333333333          0.0           40.0
# 1451    Male                80.2          0.0            7.4
#
#                  native-country income count
# 3371              United-States  <=50k     6
# 1755              United-States  <=50k     5
# 1772              United-States  <=50k     5
# 1208              United-States  <=50k     6
# 1767        United-States,India  <=50k     5
# ...                         ...    ...   ...
# 2624              United-States  <=50k     5
# 2625              United-States   >50k     1
# 5134  Canada,Cuba,United-States  <=50k     3
# 5135  Canada,Cuba,United-States   >50k     3
# 1451              United-States  <=50k     5
#
# [7704 rows x 16 columns]
